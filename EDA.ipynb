# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/mouse/Documents/GitHub/SC3020/SC3020-Lab1/games.txt", delimiter = '\t')

# %%
df.head(20)
# Out:
#    GAME_DATE_EST  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  \
# 0     22/12/2022    1610612740     126.0        0.484        0.926
# 1     22/12/2022    1610612762     120.0        0.488        0.952
# 2     21/12/2022    1610612739     114.0        0.482        0.786
# 3     21/12/2022    1610612755     113.0        0.441        0.909
# 4     21/12/2022    1610612737     108.0        0.429        1.000
# 5     21/12/2022    1610612738     112.0        0.386        0.840
# 6     21/12/2022    1610612751     143.0        0.643        0.875
# 7     21/12/2022    1610612752     106.0        0.553        0.611
# 8     21/12/2022    1610612745     110.0        0.466        0.647
# 9     21/12/2022    1610612750      99.0        0.494        0.700
# 10    21/12/2022    1610612760     101.0        0.468        0.840
# 11    21/12/2022    1610612758     134.0        0.505        0.750
# 12    21/12/2022    1610612746     126.0        0.506        0.913
# ...

# %%
np.unique(df['HOME_TEAM_WINS'])
# Out:
# array([0, 1])

# %%
df.describe()
# Out:
#        TEAM_ID_home      PTS_home   FG_PCT_home   FT_PCT_home  FG3_PCT_home  \
# count  2.665100e+04  26552.000000  26552.000000  26552.000000  26552.000000
# mean   1.610613e+09    103.455898      0.460735      0.760377      0.356023
# std    8.638670e+00     13.283370      0.056676      0.100677      0.111164
# min    1.610613e+09     36.000000      0.250000      0.143000      0.000000
# 25%    1.610613e+09     94.000000      0.422000      0.697000      0.286000
# 50%    1.610613e+09    103.000000      0.460000      0.765000      0.357000
# 75%    1.610613e+09    112.000000      0.500000      0.833000      0.429000
# max    1.610613e+09    168.000000      0.684000      1.000000      1.000000
#
#            AST_home      REB_home  HOME_TEAM_WINS
# count  26552.000000  26552.000000    26651.000000
# mean      22.823441     43.374284        0.587032
# std        5.193308      6.625769        0.492376
# min        6.000000     15.000000        0.000000
# ...

# %%
df.shape
# Out:
# (26651, 9)

# %%
len(np.unique(df['FG_PCT_home']))
# Out:
# 364

# %%
np.unique(df['FG_PCT_home'])
# Out:
# array([0.25 , 0.257, 0.266, 0.269, 0.274, 0.275, 0.277, 0.278, 0.279,
#        0.282, 0.283, 0.284, 0.286, 0.288, 0.289, 0.29 , 0.291, 0.292,
#        0.293, 0.294, 0.295, 0.296, 0.297, 0.298, 0.299, 0.3  , 0.301,
#        0.302, 0.303, 0.304, 0.305, 0.306, 0.307, 0.308, 0.309, 0.31 ,
#        0.311, 0.312, 0.313, 0.314, 0.315, 0.316, 0.317, 0.318, 0.319,
#        0.32 , 0.321, 0.322, 0.323, 0.324, 0.325, 0.326, 0.327, 0.328,
#        0.329, 0.33 , 0.333, 0.337, 0.338, 0.339, 0.34 , 0.341, 0.342,
#        0.343, 0.344, 0.345, 0.346, 0.347, 0.348, 0.349, 0.35 , 0.351,
#        0.352, 0.353, 0.354, 0.355, 0.356, 0.357, 0.358, 0.359, 0.36 ,
#        0.361, 0.362, 0.363, 0.364, 0.365, 0.366, 0.367, 0.368, 0.369,
#        0.37 , 0.371, 0.372, 0.373, 0.374, 0.375, 0.376, 0.377, 0.378,
#        0.379, 0.38 , 0.381, 0.382, 0.383, 0.384, 0.385, 0.386, 0.387,
#        0.388, 0.389, 0.39 , 0.391, 0.392, 0.393, 0.394, 0.395, 0.396,
# ...

# %%
np.mean(df[(df['FG_PCT_home'] >= 0.5) & (df['FG_PCT_home'] <= 0.8)]['FG3_PCT_home'])
# Out:
# np.float64(0.42080150680962036)
